# %% [markdown]
# # Importing Pandas and loading the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import locale

# Set the locale to German (Germany)
locale.setlocale(locale.LC_ALL, 'de_DE.UTF-8')

orders_df = pd.read_csv('orders_new.csv')
orderlines_df = pd.read_csv('order_lines_new.csv')
products_df = pd.read_csv('products_new.csv')
brands_df = pd.read_csv('brands_new.csv')

# %% [markdown]
# ## Making copies

# %%
or_df = orders_df.copy()
ol_df = orderlines_df.copy()
pr_df = products_df.copy()
br_df = brands_df.copy()

# %% [markdown]
# # Analysing...
